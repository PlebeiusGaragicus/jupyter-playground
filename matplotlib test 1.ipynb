# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 190, where=(ys > 190), facecolor='g', alpha=0.8)

plt.title("Sample Visualization")
plt.show()
